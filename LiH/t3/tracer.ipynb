# %%
import matplotlib.pyplot as plt

# %%
result = [-7.6072094241E+00, -7.6103456602E+00, -7.6131280937E+00,
          -7.6155865882E+00, -7.6177479783E+00, -7.6196365690E+00, 
          -7.6212746008E+00, -7.6226826640E+00, -7.6238800522E+00,
          -7.6248850415E+00, -7.6257150863E+00, -7.6263869291E+00,
          -7.6269166278E+00, -7.6273195140E+00, -7.6276101038E+00,
          -7.6278019834E+00, -7.6279076966E+00, -7.6279386529E+00,
          -7.6279050724E+00, -7.6278159732E+00, -7.6276792026E+00]

# %%
fig, ax = plt.subplots()
ax.plot(result, '-o')
ax.set_title("Énergie (Ha)")

plt.show()
