# %%
# Use this at the beginning of your script so that your code will be compatible with python3
from __future__ import print_function, division, unicode_literals

import numpy as np  

import warnings 
warnings.filterwarnings("ignore")  # Ignore warnings

from abipy import abilab
abilab.enable_notebook() # This line tells AbiPy we are running inside a notebook

# This line configures matplotlib to show figures embedded in the notebook.
# Replace `inline` with `notebook` in classic notebook
# %matplotlib inline

# %%
with abilab.abiopen("LiH_t5o_DEN.nc") as denfile:
    print(denfile)
    density = denfile.density
# Out:
# ================================= File Info =================================
# Name: LiH_t5o_DEN.nc
# Directory: /home/tchapet/TutoAbinit/LiH/t5
# Size: 774.05 kb
# Access Time: Tue Apr  4 20:21:09 2023
# Modification Time: Tue Apr  4 20:20:00 2023
# Change Time: Tue Apr  4 20:20:00 2023
#
# ================================= Structure =================================
# Full Formula (Li1 H1)
# Reduced Formula: LiH
# abc   :   5.291772   5.291772   5.291772
# angles:  90.000000  90.000000  90.000000
# pbc   :       True       True       True
# Sites (2)
#   #  SP            a    b    c
# ---  ----  ---------  ---  ---
#   0  Li    -0.024744    0    0
#   1  H      0.308244    0    0
#
# Abinit Spacegroup: spgid: 0, num_spatial_symmetries: 8, has_timerev: True, symmorphic: False
#
# ============================== Electronic Bands ==============================
# Number of electrons: 4.0, Fermi level: 271276023017128847723131217173739995136.000 (eV)
# nsppol: 1, nkpt: 1, mband: 3, nspinor: 1, nspden: 1
# smearing scheme: none (occopt 1), tsmear_eV: 0.272, tsmear Kelvin: 3157.7
# WARNING: Cannot compute direct and fundamental gap.
# Bandwidth: 0.000 (eV)
# Valence maximum located at kpt index 0:
#     spin: 0, kpt: [+0.000, +0.000, +0.000], name: $\Gamma$, weight: 0.000, band: 2, eig: 271276023017128847723131217173739995136.000, occ: 0.000
# TIP: Use `--verbose` to print k-point coordinates with more digits
# XC functional: PW
# ================================== Density ==================================
# Density: nspinor: 1, nsppol: 1, nspden: 1
# Mesh3D: nx=45, ny=45, nz=45
# Integrated electronic and magnetization densities in atomic spheres:
#       symbol      ntot  rsph_ang                  frac_coords
# iatom
# 0         Li  2.258076      1.28  [-0.024743772625, 0.0, 0.0]
# 1          H  0.121981      0.31    [0.30824377262, 0.0, 0.0]
# Total magnetization from unit cell integration: 0.0

# %%
density.plot_line(0, 1);

# %%
density.visualize("vesta")
# Out:
# tokens ['', 'xsf'] ext xsf
# Executing: /usr/bin/vesta  /home/tchapet/TutoAbinit/LiH/t5/__abinb_workdir__/tmpcawysekk.xsf
# (VESTA-gui:29404): Gtk-CRITICAL **: 20:22:01.077: gtk_box_gadget_distribute: assertion 'size >= 0' failed in GtkNotebook
#
# (VESTA-gui:29404): Gtk-CRITICAL **: 20:22:01.290: gtk_box_gadget_distribute: assertion 'size >= 0' failed in GtkNotebook
#
# (VESTA-gui:29404): Gtk-CRITICAL **: 20:22:02.800: gtk_box_gadget_distribute: assertion 'size >= 0' failed in GtkNotebook
# ok 1
# ok 2
# ok 3
# ok 4
# 0
